# %%
import pandas as pd

# %%
# Load in files
df_schedule = pd.read_excel(r"C:\Users\Chris Napoli\OneDrive\Desktop\Github Repo\PaupackLaxStatTracking\Test_Data\DimSchedule.xlsx", sheet_name="DimSchedule")
df_players = pd.read_excel(r"C:\Users\Chris Napoli\OneDrive\Desktop\Github Repo\PaupackLaxStatTracking\Test_Data\DimPlayers.xlsx", sheet_name="DimPlayers")
df_fact = pd.read_excel(r"C:\Users\Chris Napoli\OneDrive\Desktop\Github Repo\PaupackLaxStatTracking\Test_Data\FactTable.xlsx", sheet_name="FactTable")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 4
#       2 df_schedule = pd.read_excel(r"C:\Users\Chris Napoli\OneDrive\Desktop\Github Repo\PaupackLaxStatTracking\Test_Data\DimSchedule.xlsx", sheet_name="DimSchedule")
#       3 df_players = pd.read_excel(r"C:\Users\Chris Napoli\OneDrive\Desktop\Github Repo\PaupackLaxStatTracking\Test_Data\DimPlayers.xlsx", sheet_name="DimPlayers")
# ----> 4 df_fact = pd.read_excel(r"C:\Users\Chris Napoli\OneDrive\Desktop\Github Repo\PaupackLaxStatTracking\Test_Data\FactTable.xlsx", sheet_name="FactTable")
#
# File c:\Users\Chris Napoli\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\Chris Napoli\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File c:\Users\Chris Napoli\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File c:\Users\Chris Napoli\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\Chris Napoli\\OneDrive\\Desktop\\Github Repo\\PaupackLaxStatTracking\\Test_Data\\FactTable.xlsx'

# %%
df_schedule
# Out:
#          Date    OpponentName Won?  OppClearAtts  OppClearSuccesses  \
# 0  2025-03-08    Riverside HS    Y            18                 12
# 1  2025-03-15     Lakewood HS    N            20                 14
# 2  2025-03-22    Northview HS    Y            15                 11
# 3  2025-03-29  Summit Academy    Y            17                 10
# 4  2025-04-05    Eastbrook HS    N            22                 16
# 5  2025-04-12  Cedar Falls HS    Y            14                  9
# 6  2025-04-19    Maplewood HS    Y            16                 11
#
#    ClearAtts  ClearSuccesses  OppGoals  OppWomanUpAtts  OppWomanUpGoals  \
# 0         22              18         5               4                1
# 1         19              13         9               5                2
# 2         24              20         4               2                0
# 3         21              17         6               3                1
# 4         18              12         8               6                3
# 5         25              21         3               1                0
# 6         23              19         5               3                1
#
#    WomanUpAtts OT?  FreePosAtt  FreePosGoal  OppWomanDownGoals
# 0            6   N           3            1                  0
# 1            4   N           2            0                  1
# 2            7   N           4            2                  0
# 3            5   Y           5            2                  0
# 4            3   N           2            1                  2
# 5            8   N           6            3                  0
# 6            6   N           4            2                  0

# %%
df_players
# Out:
#    PlayerID    PlayerName  JerseyNum  Position
# 0         1   Olivia Hart          3    Attack
# 1         2     Mia Russo          7    Attack
# 2         3   Emma Torres         11  Midfield
# 3         4    Sophie Kim         14  Midfield
# 4         5    Ava Nguyen         22  Midfield
# 5         6   Chloe Banks          5   Defense
# 6         7   Riley Patel          9   Defense
# 7         8   Jenna Walsh         18   Defense
# 8         9  Natalie Cruz          2   Defense
# 9        10  Lauren Scott          1    Goalie

# %%
df_fact
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_fact
#
# NameError: name 'df_fact' is not defined
